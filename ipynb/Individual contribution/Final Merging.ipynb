# %%
import pandas as pd
d1 = pd.read_csv("Individual_contribution_2019_2020.csv")
d1.head(20)
# Out:
#       CMTE_ID TRANSACTION_DT  TRANSACTION_AMT                 STATE  \
# 0   C00703975     2020-01-10            250.0          Pennsylvania
# 1   C00075820     2020-01-10             35.0             Tennessee
# 2   C00075820     2020-01-10             50.0             Tennessee
# 3   C00697441     2020-01-10             13.0  District of Columbia
# 4   C00697441     2020-01-10             32.0          Pennsylvania
# 5   C00696948     2020-01-10             27.0                Oregon
# 6   C00696948     2020-01-10             10.0         Massachusetts
# 7   C00696948     2020-01-10             10.0              New York
# 8   C00075820     2020-01-10             25.0                 Texas
# 9   C00696948     2020-01-10              2.0            California
# 10  C00696948     2020-01-10             27.0            California
# 11  C00703975     2020-01-10            100.0               Florida
# 12  C00697441     2020-01-10             10.0            California
# ...

# %%
d1.shape
# Out:
# (34465962, 9)

# %%
d1.tail(10)
# Out:
#             CMTE_ID TRANSACTION_DT  TRANSACTION_AMT           STATE  \
# 34465952  C00010603     2020-12-31            100.0     Connecticut
# 34465953  C00000935     2020-12-31             19.0         Florida
# 34465954  C00009639     2020-12-31             12.0  North Carolina
# 34465955  C00010603     2020-12-31             10.0      New Mexico
# 34465956  C00027466     2020-12-31             16.0        New York
# 34465957  C00000935     2020-12-31             50.0        New York
# 34465958  C00000935     2020-12-31             15.0        New York
# 34465959  C00000935     2020-12-31             15.0        Michigan
# 34465960  C00009639     2020-12-31             14.0        Maryland
# 34465961  C00401224     2020-12-31              1.0      California
#
#            ENTITY_TP                     TRANSACTION_TP                  NAME  \
# 34465952  Individual       (15E) Earmarked Contribution         SEAMAN, LINDA
# ...

# %%
d1.dtypes
# Out:
# CMTE_ID             object
# TRANSACTION_DT      object
# TRANSACTION_AMT    float64
# STATE               object
# ENTITY_TP           object
# TRANSACTION_TP      object
# NAME                object
# EMPLOYER            object
# OCCUPATION          object
# dtype: object

# %%
d1['ENTITY_TP'].unique()
# Out:
# array(['Individual', 'Candidate', 'Committee', 'Organization',
#        'Political Action Committee', 'Candidate Committee',
#        'Party Organization'], dtype=object)

# %%
# Check for literal "NONE" string
print("=== CHECKING FOR 'NONE' STRING VALUE ===")
print(f"EMPLOYER with 'NONE': {(d1['EMPLOYER'] == 'NONE').sum():,}")
print(f"OCCUPATION with 'NONE': {(d1['OCCUPATION'] == 'NONE').sum():,}")
print()

# Case-insensitive check (in case it's "none", "None", etc.)
print("=== CASE-INSENSITIVE CHECK ===")
print(f"EMPLOYER with 'NONE' (any case): {(d1['EMPLOYER'].str.upper() == 'NONE').sum():,}")
print(f"OCCUPATION with 'NONE' (any case): {(d1['OCCUPATION'].str.upper() == 'NONE').sum():,}")
print()
# Out:
# === CHECKING FOR 'NONE' STRING VALUE ===
# EMPLOYER with 'NONE': 0
# OCCUPATION with 'NONE': 0
#
# === CASE-INSENSITIVE CHECK ===
# EMPLOYER with 'NONE' (any case): 0
# OCCUPATION with 'NONE' (any case): 0

# %%
# Replace NONE with Undisclosed (case-insensitive)
d1['EMPLOYER'] = d1['EMPLOYER'].str.replace('NONE', 'Undisclosed', regex=True)
d1['OCCUPATION'] = d1['OCCUPATION'].str.replace('NONE', 'Undisclosed', regex=True)

# Verify the change
print("After replacement:")
print(f"EMPLOYER = 'NONE': {(d1['EMPLOYER'].str.upper() == 'NONE').sum():,}")
print(f"EMPLOYER = 'Undisclosed': {(d1['EMPLOYER'] == 'Undisclosed').sum():,}")
print()
print(f"OCCUPATION = 'NONE': {(d1['OCCUPATION'].str.upper() == 'NONE').sum():,}")
print(f"OCCUPATION = 'Undisclosed': {(d1['OCCUPATION'] == 'Undisclosed').sum():,}")
# Out:
# After replacement:
# EMPLOYER = 'NONE': 0
# EMPLOYER = 'Undisclosed': 4,634,793
#
# OCCUPATION = 'NONE': 0
# OCCUPATION = 'Undisclosed': 1,002,454

# %%
# Check for literal "NONE" string
print("=== CHECKING FOR 'NONE' STRING VALUE ===")
print(f"EMPLOYER with 'NONE': {(d1['EMPLOYER'] == 'NONE').sum():,}")
print(f"OCCUPATION with 'NONE': {(d1['OCCUPATION'] == 'NONE').sum():,}")
print()

# Case-insensitive check (in case it's "none", "None", etc.)
print("=== CASE-INSENSITIVE CHECK ===")
print(f"EMPLOYER with 'NONE' (any case): {(d1['EMPLOYER'].str.upper() == 'NONE').sum():,}")
print(f"OCCUPATION with 'NONE' (any case): {(d1['OCCUPATION'].str.upper() == 'NONE').sum():,}")
print()
# Out:
# === CHECKING FOR 'NONE' STRING VALUE ===
# EMPLOYER with 'NONE': 0
# OCCUPATION with 'NONE': 0
#
# === CASE-INSENSITIVE CHECK ===
# EMPLOYER with 'NONE' (any case): 0
# OCCUPATION with 'NONE' (any case): 0

# %%
d1['EMPLOYER'].unique() == 'NONE'
# Out:
# array([False, False, False, ..., False, False, False])

# %%
d1['OCCUPATION'].unique() == 'NONE'
# Out:
# array([False, False, False, ..., False, False, False])

# %%
# Keep these entity types
keep_entities = ['Individual', 'Candidate', 'Committee', 'Candidate Committee']

# Filter the dataset
d1 = d1[d1['ENTITY_TP'].isin(keep_entities)].copy()

print(f"Rows after filtering: {len(d1):,}")
print(f"Entity types kept:\n{d1['ENTITY_TP'].value_counts()}")
# Out:
# Rows after filtering: 34,447,155
# Entity types kept:
# ENTITY_TP
# Individual             34435869
# Candidate                  6098
# Committee                  4746
# Candidate Committee         442
# Name: count, dtype: int64

# %%
d1.shape
# Out:
# (34447155, 9)

# %%
import pandas as pd

# Assuming your dataframe is called df
# and TRANSACTION_DT is already in datetime format

# If not yet converted:
d1["TRANSACTION_DT"] = pd.to_datetime(d1["TRANSACTION_DT"], errors="coerce")

# Define date range
start_date = "2020-09-01"
end_date = "2020-12-31"

# Filter data within the range (inclusive)
filtered_df = d1[
    (d1["TRANSACTION_DT"] >= start_date) &
    (d1["TRANSACTION_DT"] <= end_date)
]

# Optional: check number of rows and preview
print(f"Filtered rows: {len(filtered_df)}")
print(filtered_df.head())
# Out:
# Filtered rows: 20557859
#             CMTE_ID TRANSACTION_DT  TRANSACTION_AMT           STATE  \
# 13898780  C00703975     2020-09-01             15.0  North Carolina
# 13898781  C00027466     2020-09-01            100.0         Florida
# 13898782  C00003418     2020-09-01            300.0           Texas
# 13898783  C00443689     2020-09-01              5.0  North Carolina
# 13898784  C00401224     2020-09-01              1.0   Massachusetts
#
#            ENTITY_TP                     TRANSACTION_TP  \
# 13898780  Individual       (15E) Earmarked Contribution
# 13898781  Individual       (15E) Earmarked Contribution
# 13898782  Individual  (15) Contribution from Individual
# 13898783  Individual       (15E) Earmarked Contribution
# 13898784  Individual  (15) Contribution from Individual
#
#                                 NAME                 EMPLOYER  \
# 13898780               TEAGUE, PATTI          KELLER WILLIAMS
# 13898781           CIVELLO, NELSON D                  RETIRED
# ...

# %%
filtered_df.shape
# Out:
# (20557859, 9)

# %%
filtered_df.dtypes
# Out:
# CMTE_ID                    object
# TRANSACTION_DT     datetime64[ns]
# TRANSACTION_AMT           float64
# STATE                      object
# ENTITY_TP                  object
# TRANSACTION_TP             object
# NAME                       object
# EMPLOYER                   object
# OCCUPATION                 object
# dtype: object

# %%
import pandas as pd
d2 = pd.read_csv("Individual_contribution_2021_2022.csv")

# %%
d2.head(20)
# Out:
#       CMTE_ID TRANSACTION_DT  TRANSACTION_AMT       STATE   ENTITY_TP  \
# 0   C00618371     2021-01-10            100.0    Missouri  Individual
# 1   C00633404     2021-01-10              8.0    New York  Individual
# 2   C00633404     2021-01-10              5.0     Alabama  Individual
# 3   C00633404     2021-01-10            300.0    New York  Individual
# 4   C00633404     2021-01-10           1000.0     Florida  Individual
# 5   C00633404     2021-01-10             25.0  Washington  Individual
# 6   C00633404     2021-01-10             25.0  Washington  Individual
# 7   C00633404     2021-01-10             25.0  Washington  Individual
# 8   C00633404     2021-01-10             25.0  Washington  Individual
# 9   C00633404     2021-01-10             15.0  Washington  Individual
# 10  C00639591     2021-01-10             50.0    New York  Individual
# 11  C00639591     2021-01-10             50.0    New York  Individual
# ...

# %%
d2.tail(10)
# Out:
#             CMTE_ID TRANSACTION_DT  TRANSACTION_AMT           STATE  \
# 31610394  C00000935     2022-12-31             25.0      New Jersey
# 31610395  C00000935     2022-12-31             35.0      New Jersey
# 31610396  C00000935     2022-12-31              6.0         Georgia
# 31610397  C00000935     2022-12-31              5.0  North Carolina
# 31610398  C00000935     2022-12-31             20.0        Virginia
# 31610399  C00000935     2022-12-31             50.0        Missouri
# 31610400  C00000935     2022-12-31             15.0    Pennsylvania
# 31610401  C00000935     2022-12-31             25.0    Pennsylvania
# 31610402  C00000935     2022-12-31             25.0      California
# 31610403  C00042366     2022-12-31             25.0      California
#
#            ENTITY_TP                TRANSACTION_TP                NAME  \
# 31610394  Individual  (15E) Earmarked Contribution    HENDERSON, JAMES
# 31610395  Individual  (15E) Earmarked Contribution    HENDERSON, JAMES
# ...

# %%
d2.shape
# Out:
# (31610404, 9)

# %%
# Check for literal "NONE" string
print("=== CHECKING FOR 'NONE' STRING VALUE ===")
print(f"EMPLOYER with 'NONE': {(d2['EMPLOYER'] == 'NONE').sum():,}")
print(f"OCCUPATION with 'NONE': {(d2['OCCUPATION'] == 'NONE').sum():,}")
print()

# Case-insensitive check (in case it's "none", "None", etc.)
print("=== CASE-INSENSITIVE CHECK ===")
print(f"EMPLOYER with 'NONE' (any case): {(d2['EMPLOYER'].str.upper() == 'NONE').sum():,}")
print(f"OCCUPATION with 'NONE' (any case): {(d2['OCCUPATION'].str.upper() == 'NONE').sum():,}")
print()
# Out:
# === CHECKING FOR 'NONE' STRING VALUE ===
# EMPLOYER with 'NONE': 1,455,855
# OCCUPATION with 'NONE': 75,198
#
# === CASE-INSENSITIVE CHECK ===
# EMPLOYER with 'NONE' (any case): 1,455,855
# OCCUPATION with 'NONE' (any case): 75,198

# %%
# Replace NONE with Undisclosed (case-insensitive)
d2['EMPLOYER'] = d2['EMPLOYER'].str.replace('NONE', 'Undisclosed', regex=True)
d2['OCCUPATION'] = d2['OCCUPATION'].str.replace('NONE', 'Undisclosed', regex=True)

# Verify the change
print("After replacement:")
print(f"EMPLOYER = 'NONE': {(d2['EMPLOYER'].str.upper() == 'NONE').sum():,}")
print(f"EMPLOYER = 'Undisclosed': {(d2['EMPLOYER'] == 'Undisclosed').sum():,}")
print()
print(f"OCCUPATION = 'NONE': {(d2['OCCUPATION'].str.upper() == 'NONE').sum():,}")
print(f"OCCUPATION = 'Undisclosed': {(d2['OCCUPATION'] == 'Undisclosed').sum():,}")
# Out:
# After replacement:
# EMPLOYER = 'NONE': 0
# EMPLOYER = 'Undisclosed': 4,081,373
#
# OCCUPATION = 'NONE': 0
# OCCUPATION = 'Undisclosed': 601,111

# %%
# Check for literal "NONE" string
print("=== CHECKING FOR 'NONE' STRING VALUE ===")
print(f"EMPLOYER with 'NONE': {(d2['EMPLOYER'] == 'NONE').sum():,}")
print(f"OCCUPATION with 'NONE': {(d2['OCCUPATION'] == 'NONE').sum():,}")
print()

# Case-insensitive check (in case it's "none", "None", etc.)
print("=== CASE-INSENSITIVE CHECK ===")
print(f"EMPLOYER with 'NONE' (any case): {(d2['EMPLOYER'].str.upper() == 'NONE').sum():,}")
print(f"OCCUPATION with 'NONE' (any case): {(d2['OCCUPATION'].str.upper() == 'NONE').sum():,}")
print()
# Out:
# === CHECKING FOR 'NONE' STRING VALUE ===
# EMPLOYER with 'NONE': 0
# OCCUPATION with 'NONE': 0
#
# === CASE-INSENSITIVE CHECK ===
# EMPLOYER with 'NONE' (any case): 0
# OCCUPATION with 'NONE' (any case): 0

# %%
# Keep these entity types
keep_entities = ['Individual', 'Candidate', 'Committee', 'Candidate Committee']

# Filter the dataset
d2 = d2[d2['ENTITY_TP'].isin(keep_entities)].copy()

print(f"Rows after filtering: {len(d2):,}")
print(f"Entity types kept:\n{d2['ENTITY_TP'].value_counts()}")
# Out:
# Rows after filtering: 31,591,525
# Entity types kept:
# ENTITY_TP
# Individual             31579321
# Candidate                 11026
# Committee                   922
# Candidate Committee         256
# Name: count, dtype: int64

# %%
d2.shape
# Out:
# (31610404, 9)

# %%
d2.head()
# Out:
#      CMTE_ID TRANSACTION_DT  TRANSACTION_AMT     STATE   ENTITY_TP  \
# 0  C00618371     2021-01-10            100.0  Missouri  Individual
# 1  C00633404     2021-01-10              8.0  New York  Individual
# 2  C00633404     2021-01-10              5.0   Alabama  Individual
# 3  C00633404     2021-01-10            300.0  New York  Individual
# 4  C00633404     2021-01-10           1000.0   Florida  Individual
#
#                  TRANSACTION_TP              NAME  \
# 0  (15E) Earmarked Contribution      TOWEY, NANCY
# 1  (15E) Earmarked Contribution   POGGIOLI, SUSAN
# 2  (15E) Earmarked Contribution     PITTARD, JOEL
# 3  (15E) Earmarked Contribution  PERSHING, SANDRA
# 4  (15E) Earmarked Contribution     RAZACK, ADNAN
#
#                       EMPLOYER      OCCUPATION
# 0                       USBANK  BRANCH MANAGER
# 1  AURORA PRODUCTIONS INTL INC      ACCOUNTANT
# 2                    LEE OBGYN       PHYSICIAN
# 3                 NOT EMPLOYED    NOT EMPLOYED
# ...

# %%
d2.dtypes
# Out:
# CMTE_ID                    object
# TRANSACTION_DT     datetime64[ns]
# TRANSACTION_AMT           float64
# STATE                      object
# ENTITY_TP                  object
# TRANSACTION_TP             object
# NAME                       object
# EMPLOYER                   object
# OCCUPATION                 object
# dtype: object

# %%
# Convert date column to datetime
d2["TRANSACTION_DT"] = pd.to_datetime(d2["TRANSACTION_DT"], errors="coerce")

# %%
import pandas as pd
d3 = pd.read_csv("Individual_contribution_2023_2024.csv")

# %%
d3.head(20)
# Out:
#       CMTE_ID TRANSACTION_DT  TRANSACTION_AMT          STATE   ENTITY_TP  \
# 0   C00770941     2023-01-10            100.0       Missouri  Individual
# 1   C00770941     2023-01-10              1.0     New Jersey  Individual
# 2   C00770941     2023-01-10             10.0     New Jersey  Individual
# 3   C00770941     2023-01-10              7.0     New Jersey  Individual
# 4   C00401224     2023-01-10             10.0     California  Individual
# 5   C00770941     2023-01-10             20.0     New Jersey  Individual
# 6   C00770941     2023-01-10             50.0         Oregon  Individual
# 7   C00770941     2023-01-10              3.0          Texas  Individual
# 8   C00748582     2023-01-10            250.0  Massachusetts  Individual
# 9   C00401224     2023-01-10              1.0        Arizona  Individual
# 10  C00770941     2023-01-10             10.0     New Jersey  Individual
# 11  C00678987     2023-01-10           1000.0   Pennsylvania  Individual
# ...

# %%
d3.tail(10)
# Out:
#             CMTE_ID TRANSACTION_DT  TRANSACTION_AMT          STATE  \
# 47343822  C00770941     2024-12-31              7.0       New York
# 47343823  C00414896     2024-12-31            115.0     California
# 47343824  C00414896     2024-12-31             28.0  Massachusetts
# 47343825  C00414896     2024-12-31             57.0     California
# 47343826  C00414896     2024-12-31            300.0     California
# 47343827  C00414896     2024-12-31             28.0     California
# 47343828  C00414896     2024-12-31            115.0     California
# 47343829  C00414896     2024-12-31            115.0       Virginia
# 47343830  C00414896     2024-12-31            115.0  New Hampshire
# 47343831  C00027466     2024-12-31             25.0       Illinois
#
#            ENTITY_TP                     TRANSACTION_TP  \
# 47343822  Individual       (15E) Earmarked Contribution
# 47343823  Individual  (15) Contribution from Individual
# 47343824  Individual  (15) Contribution from Individual
# ...

# %%
d3.shape
# Out:
# (47343832, 9)

# %%
# Check for literal "NONE" string
print("=== CHECKING FOR 'NONE' STRING VALUE ===")
print(f"EMPLOYER with 'NONE': {(d3['EMPLOYER'] == 'NONE').sum():,}")
print(f"OCCUPATION with 'NONE': {(d3['OCCUPATION'] == 'NONE').sum():,}")
print()

# Case-insensitive check (in case it's "none", "None", etc.)
print("=== CASE-INSENSITIVE CHECK ===")
print(f"EMPLOYER with 'NONE' (any case): {(d3['EMPLOYER'].str.upper() == 'NONE').sum():,}")
print(f"OCCUPATION with 'NONE' (any case): {(d3['OCCUPATION'].str.upper() == 'NONE').sum():,}")
print()
# Out:
# === CHECKING FOR 'NONE' STRING VALUE ===
# EMPLOYER with 'NONE': 1,495,518
# OCCUPATION with 'NONE': 32,980
#
# === CASE-INSENSITIVE CHECK ===
# EMPLOYER with 'NONE' (any case): 1,495,518
# OCCUPATION with 'NONE' (any case): 32,980

# %%
# Replace NONE with Undisclosed (case-insensitive)
d2['EMPLOYER'] = d2['EMPLOYER'].str.replace('(?i)^none$', 'Undisclosed', regex=True)
d2['OCCUPATION'] = d2['OCCUPATION'].str.replace('(?i)^none$', 'Undisclosed', regex=True)

# Verify the change
print("After replacement:")
print(f"EMPLOYER = 'NONE': {(d2['EMPLOYER'].str.upper() == 'NONE').sum():,}")
print(f"EMPLOYER = 'Undisclosed': {(d2['EMPLOYER'] == 'Undisclosed').sum():,}")
print()
print(f"OCCUPATION = 'NONE': {(d2['OCCUPATION'].str.upper() == 'NONE').sum():,}")
print(f"OCCUPATION = 'Undisclosed': {(d2['OCCUPATION'] == 'Undisclosed').sum():,}")
# Out:
# After replacement:
# EMPLOYER = 'NONE': 0
# EMPLOYER = 'Undisclosed': 4,081,373
#
# OCCUPATION = 'NONE': 0
# OCCUPATION = 'Undisclosed': 601,111

# %%
# Check for literal "NONE" string
print("=== CHECKING FOR 'NONE' STRING VALUE ===")
print(f"EMPLOYER with 'NONE': {(d3['EMPLOYER'] == 'NONE').sum():,}")
print(f"OCCUPATION with 'NONE': {(d3['OCCUPATION'] == 'NONE').sum():,}")
print()

# Case-insensitive check (in case it's "none", "None", etc.)
print("=== CASE-INSENSITIVE CHECK ===")
print(f"EMPLOYER with 'NONE' (any case): {(d3['EMPLOYER'].str.upper() == 'NONE').sum():,}")
print(f"OCCUPATION with 'NONE' (any case): {(d3['OCCUPATION'].str.upper() == 'NONE').sum():,}")
print()
# Out:
# === CHECKING FOR 'NONE' STRING VALUE ===
# EMPLOYER with 'NONE': 1,495,518
# OCCUPATION with 'NONE': 32,980
#
# === CASE-INSENSITIVE CHECK ===
# EMPLOYER with 'NONE' (any case): 1,495,518
# OCCUPATION with 'NONE' (any case): 32,980

# %%
# Keep these entity types
keep_entities = ['Individual', 'Candidate', 'Committee', 'Candidate Committee']

# Filter the dataset
d3 = d3[d3['ENTITY_TP'].isin(keep_entities)].copy()

print(f"Rows after filtering: {len(d3):,}")
print(f"Entity types kept:\n{d3['ENTITY_TP'].value_counts()}")
# Out:
# Rows after filtering: 47,318,912
# Entity types kept:
# ENTITY_TP
# Individual             47307932
# Candidate                  9461
# Committee                  1220
# Candidate Committee         299
# Name: count, dtype: int64

# %%
d3.shape
# Out:
# (47318912, 9)

# %%
d3.dtypes
# Out:
# CMTE_ID                    object
# TRANSACTION_DT     datetime64[ns]
# TRANSACTION_AMT           float64
# STATE                      object
# ENTITY_TP                  object
# TRANSACTION_TP             object
# NAME                       object
# EMPLOYER                   object
# OCCUPATION                 object
# dtype: object

# %%
# Convert date column to datetime
d3["TRANSACTION_DT"] = pd.to_datetime(d3["TRANSACTION_DT"], errors="coerce")

# %% [markdown]
# # MERGING

# %%
# Concatenate all three datasets
df_combined = pd.concat([filtered_df, d2, d3], ignore_index=True)

# Check combined dataset
print("Combined shape:", df_combined.shape)
print("\nDate range:")
print("Start:", df_combined['TRANSACTION_DT'].min())
print("End:", df_combined['TRANSACTION_DT'].max())
print("\nNull values:")
print(df_combined.isnull().sum())
# Out:
# Combined shape: (99487175, 9)
#
# Date range:
# Start: 2020-09-01 00:00:00
# End: 2024-12-31 00:00:00
#
# Null values:
# CMTE_ID            0
# TRANSACTION_DT     0
# TRANSACTION_AMT    0
# STATE              0
# ENTITY_TP          0
# TRANSACTION_TP     0
# NAME               0
# EMPLOYER           0
# OCCUPATION         0
# dtype: int64

# %%
# Save cleaned dataset for Tableau
df_combined.to_csv("Individual_contribution_2020_2024.csv", index=False)
print("✅ File saved as: Individual_contribution_2020_2024.csv")
# Out:
# ✅ File saved as: Individual_contribution_2020_2024.csv

# %%
df_combined.shape
# Out:
# (99487175, 9)

# %%
df_combined.isnull().sum()
# Out:
# CMTE_ID            0
# TRANSACTION_DT     0
# TRANSACTION_AMT    0
# STATE              0
# ENTITY_TP          0
# TRANSACTION_TP     0
# NAME               0
# EMPLOYER           0
# OCCUPATION         0
# dtype: int64
