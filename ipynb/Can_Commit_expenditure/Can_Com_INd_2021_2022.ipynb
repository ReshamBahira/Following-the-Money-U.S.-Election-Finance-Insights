# %%
#(MASTER)
import os
import pandas as pd
import csv

input_file = "itpas2021_2022.txt"
output_file = "itpas2021_2022.csv"

# FEC column names (21 fields)
# FEC PAS2 File Columns

columns = [
    'CMTE_ID',
    'AMNDT_IND',
    'RPT_TP',
    'TRANSACTION_PGI',
    'IMAGE_NUM',
    'TRANSACTION_TP',
    'ENTITY_TP',
    'NAME',
    'CITY',
    'STATE',
    'ZIP_CODE',
    'EMPLOYER',
    'OCCUPATION',
    'TRANSACTION_DT',
    'TRANSACTION_AMT',
    'OTHER_ID',
    'CAND_ID',
    'TRAN_ID',
    'FILE_NUM',
    'MEMO_CD',
    'MEMO_TEXT',
    'SUB_ID'
]


# ---------- 1) Fast line count (for percentage progress) ----------
def count_lines(path, bufsize=64 * 1024 * 1024):  # 64 MB blocks
    total = 0
    with open(path, "rb") as fh:
        while True:
            block = fh.read(bufsize)
            if not block:
                break
            total += block.count(b"\n")
    return total

print("📏 Counting total lines (quick scan)...")
total_rows = count_lines(input_file)
print(f"🔢 Total lines detected: {total_rows:,}")

# ---------- 2) Stream convert with progress ----------
chunksize = 500_000  # safe for 8 GB RAM
first_chunk = True
rows_processed = 0

reader = pd.read_csv(
    input_file,
    sep="|",
    names=columns,
    dtype=str,
    chunksize=chunksize,
    engine="python",        # tolerant parser
    on_bad_lines="skip",    # skip malformed rows (e.g., extra '|')
    encoding="utf-8",
    encoding_errors="ignore",
    quoting=csv.QUOTE_NONE, # treat quotes literally
    escapechar="\\"
)

for chunk in reader:
    # Write incrementally
    chunk.to_csv(output_file, mode="a", index=False, header=first_chunk)
    first_chunk = False

    # Update progress
    rows_processed += len(chunk)
    pct = (rows_processed / total_rows) * 100 if total_rows else 0.0
    print(f"✅ Processed {rows_processed:,} rows ({pct:.2f}%)")

print(f"\n🎉 Conversion complete!\n💾 Saved as: {output_file}\n📊 Total rows written: {rows_processed:,}")
# Out:
# 📏 Counting total lines (quick scan)...
# 🔢 Total lines detected: 751,519
# ✅ Processed 500,000 rows (66.53%)
# ✅ Processed 751,519 rows (100.00%)
#
# 🎉 Conversion complete!
# 💾 Saved as: itpas2021_2022.csv
# 📊 Total rows written: 751,519

# %%
import pandas as pd

d1 = pd.read_csv("itpas2021_2022.csv")
# Out:
# /var/folders/jx/5_4tbf8x201bqq6y2fp_5s740000gn/T/ipykernel_25051/3218711832.py:3: DtypeWarning: Columns (10,11,12,19,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   d1 = pd.read_csv("itpas2021_2022.csv")

# %%
d1.columns
# Out:
# Index(['CMTE_ID', 'AMNDT_IND', 'RPT_TP', 'TRANSACTION_PGI', 'IMAGE_NUM',
#        'TRANSACTION_TP', 'ENTITY_TP', 'NAME', 'CITY', 'STATE', 'ZIP_CODE',
#        'EMPLOYER', 'OCCUPATION', 'TRANSACTION_DT', 'TRANSACTION_AMT',
#        'OTHER_ID', 'CAND_ID', 'TRAN_ID', 'FILE_NUM', 'MEMO_CD', 'MEMO_TEXT',
#        'SUB_ID'],
#       dtype='object')

# %%
keep_cols = ['CMTE_ID', 'NAME', 'TRANSACTION_DT', 'TRANSACTION_AMT', 'CAND_ID','ENTITY_TP']

# %%
# Relevant columns for your project
relevant_columns = [
    'NAME',
    'CAND_ID',
    'CMTE_ID',
    'TRANSACTION_DT',
    'TRANSACTION_AMT',
    'TRANSACTION_PGI',
    'ENTITY_TP',
    'STATE',
    'TRANSACTION_TP'
]

# Filter your dataframe
d1_filtered = d1[relevant_columns]

# %%
d1_filtered.head(20)
# Out:
#                                NAME    CAND_ID    CMTE_ID  TRANSACTION_DT  \
# 0      GEORGIANS FOR KELLY LOEFFLER  S0GA00526  C00761528      12242020.0
# 1                 PERDUE FOR SENATE  S4GA11285  C00761528      12242020.0
# 2               WARNOCK FOR GEORGIA  S0GA00559  C00710780      11172020.0
# 3      JAIME HARRISON FOR US SENATE  S0SC00289  C00710780      10272020.0
# 4             JON OSSOFF FOR SENATE  S8GA00180  C00710780      11172020.0
# 5               MICHELLE FOR KANSAS  H0KS02196  C00710780      10132020.0
# 6            FRIENDS OF DICK DURBIN  S6IL00151  C00364471       1082021.0
# 7            FRIENDS OF DICK DURBIN  S6IL00151  C00364471       1082021.0
# 8   FIREARMS POLICY COALITION, INC.  S8GA00180  C00760454      12162020.0
# 9   FIREARMS POLICY COALITION, INC.  S0GA00559  C00760454      12162020.0
# 10  FIREARMS POLICY COALITION, INC.  S8GA00180  C00760454      12162020.0
# 11  FIREARMS POLICY COALITION, INC.  S0GA00559  C00760454      12162020.0
# 12  FIREARMS POLICY COALITION, INC.  S0GA00559  C00760454      12172020.0
# 13  FIREARMS POLICY COALITION, INC.  S0GA00559  C00760454      12172020.0
# 14  FIREARMS POLICY COALITION, INC.  S8GA00180  C00760454      12172020.0
# 15  FIREARMS POLICY COALITION, INC.  S8GA00180  C00760454      12172020.0
# 16              NEWSMAX MEDIA, INC.  S8GA00180  C00760454      12162020.0
# 17              NEWSMAX MEDIA, INC.  S0GA00559  C00760454      12162020.0
# 18  FIREARMS POLICY COALITION, INC.  S8GA00180  C00760454      12192020.0
# 19  FIREARMS POLICY COALITION, INC.  S8GA00180  C00760454      12232020.0
#
#     TRANSACTION_AMT TRANSACTION_PGI ENTITY_TP STATE TRANSACTION_TP
# 0              2000           R2021       CCM    GA            24K
# 1              2000           R2021       CCM    GA            24K
# 2              1500           G2020       CCM    GA            24K
# 3              1500           G2020       CCM    SC            24K
# 4              1500           G2020       CCM    GA            24K
# 5              1500           G2020       CCM    KS            24K
# 6              2500           P2026       PAC    IL            24K
# 7             -2500               P       PAC    IL            24K
# 8               171           R2021       ORG    CA            24A
# 9               171           R2021       ORG    CA            24A
# 10              111           R2021       ORG    CA            24A
# 11              111           R2021       ORG    CA            24A
# 12               56           R2021       ORG    CA            24A
# 13               75           R2021       ORG    CA            24A
# 14               75           R2021       ORG    CA            24A
# 15               56           R2021       ORG    CA            24A
# 16             1877           R2021       ORG    FL            24A
# 17             1877           R2021       ORG    FL            24A
# 18               49           R2021       ORG    CA            24A
# 19              130           R2021       ORG    CA            24A

# %%
d1_filtered.shape
# Out:
# (751519, 9)

# %%
d1_filtered.isnull().sum()
# Out:
# NAME               4533
# CAND_ID            1323
# CMTE_ID               0
# TRANSACTION_DT     5289
# TRANSACTION_AMT       0
# TRANSACTION_PGI     915
# ENTITY_TP          6264
# STATE              4746
# TRANSACTION_TP        0
# dtype: int64

# %%
d1_filtered['TRANSACTION_PGI'].unique()
# Out:
# array(['R2021', 'G2020', 'P2026', 'P', 'G2024', 'R2020', 'G2018', 'P2020',
#        'S2021', 'P2024', 'P2022', 'S2020', 'P2021', 'G2021', 'G2022',
#        'O2021', nan, 'C2022', 'P2019', 'G2023', 'G2026', 'P2017', 'G',
#        'E', 'G2019', 'S2121', 'G2017', 'P2018', 'P2025', 'E2020', 'C2021',
#        'R', 'O2022', 'P2500', 'C2024', 'E2022', 'R2022', 'G2016', 'P1500',
#        'P2023', 'E2021', 'S2500', 'S', 'S2022', 'P2002', 'P2000', 'P2075',
#        'P2016', 'P1000', 'P5000', 'P2012', 'O2020', 'R2016', 'G2012',
#        'P2015', 'P5107', 'G6555', 'P2010', 'O', 'G2010', 'G1000', 'G2002',
#        'G2014', 'P2028', '2022', 'C2020', 'P2900', 'G2500', 'P202',
#        'G5000', 'P2202', 'P2027', 'G22', 'G2202', 'C', 'G2922', 'G2028',
#        'G1411', 'G2008', 'S2023', 'G2006', 'G2025', 'S2024', 'G2000',
#        'G202', 'G1108', 'O2012', 'R2024'], dtype=object)

# %%
# Filter for presidential elections only
presidential_cycles = ['P2020', 'G2020', 'P2024', 'G2024']
df_presidential = d1_filtered[d1_filtered['TRANSACTION_PGI'].isin(presidential_cycles)]

# %%
df_presidential.shape
# Out:
# (432034, 9)

# %%
df_presidential.to_csv("itpas2021_2022_filtered.csv", index=False)

# %%
df_presidential['CAND_ID'].unique()
# Out:
# array(['S0GA00559', 'S0SC00289', 'S8GA00180', ..., 'H2NE02132',
#        'H0GA13032', 'S2LA00150'], dtype=object)

# %%
df_presidential = df_presidential[df_presidential['TRANSACTION_PGI'].isin(['P2020', 'G2020', 'P2024', 'G2024'])]
df_presidential = df_presidential[df_presidential['CAND_ID'].str.startswith('P', na=False)]

# %%
df_presidential['CAND_ID'].unique()
# Out:
# array(['P80001571', 'P80000722', 'P60007168', 'P60006723', 'P00009795',
#        'P40004574', 'P00009423', 'P40011686', 'P00006486', 'P00009290'],
#       dtype=object)

# %%
df_presidential.shape
# Out:
# (1041, 9)

# %%
df_presidential.isnull().sum()
# Out:
# NAME                 0
# CAND_ID              0
# CMTE_ID              0
# TRANSACTION_DT     184
# TRANSACTION_AMT      0
# TRANSACTION_PGI      0
# ENTITY_TP            1
# STATE                5
# TRANSACTION_TP       0
# dtype: int64

# %%
df_presidential.head(20)
# Out:
#                 NAME    CAND_ID    CMTE_ID  TRANSACTION_DT  TRANSACTION_AMT  \
# 133  RALLY CAMPAIGNS  P80001571  C00756635       1052021.0            30000
# 134  RALLY CAMPAIGNS  P80000722  C00756635       1052021.0            30000
# 851      STATES MADE  P80000722  C00646877       1082021.0              573
# 944       TOSKR, INC  P80000722  C00620971       1012021.0              106
# 945         FACEBOOK  P80000722  C00620971       1012021.0             4947
# 946       TOSKR, INC  P80001571  C00620971       1012021.0               82
# 947       TOSKR, INC  P80001571  C00620971       1012021.0               25
# 948         FACEBOOK  P80000722  C00620971       1012021.0             7500
# 949       TOSKR, INC  P80000722  C00620971       1012021.0              515
# 950       TOSKR, INC  P80000722  C00620971       1012021.0              266
# 951       TOSKR, INC  P80001571  C00620971       1012021.0               46
# 953         FACEBOOK  P80001571  C00620971       1012021.0               87
# 954       TOSKR, INC  P80000722  C00620971       1012021.0             6879
# 955       TOSKR, INC  P80001571  C00620971       1012021.0              332
# 956       TOSKR, INC  P80000722  C00620971       1012021.0            14220
# 957       TOSKR, INC  P80000722  C00620971       1012021.0              177
# 958       TOSKR, INC  P80000722  C00620971       1012021.0             5332
# 959         FACEBOOK  P80000722  C00620971       1012021.0            19515
# 962       TOSKR, INC  P80000722  C00620971       1012021.0            12039
# 963       TOSKR, INC  P80000722  C00620971       1012021.0              622
#
#     TRANSACTION_PGI ENTITY_TP STATE TRANSACTION_TP
# 133           G2020       ORG    CA            24A
# 134           G2020       ORG    CA            24E
# 851           G2020       ORG    CA            24E
# 944           G2020       ORG    CA            24E
# 945           G2020       ORG    CA            24E
# 946           G2020       ORG    CA            24A
# 947           G2020       ORG    CA            24A
# 948           G2020       ORG    CA            24E
# 949           G2020       ORG    CA            24E
# 950           G2020       ORG    CA            24E
# 951           G2020       ORG    CA            24A
# 953           G2020       ORG    CA            24A
# 954           G2020       ORG    CA            24E
# 955           G2020       ORG    CA            24A
# 956           G2020       ORG    CA            24E
# 957           G2020       ORG    CA            24E
# 958           G2020       ORG    CA            24E
# 959           G2020       ORG    CA            24E
# 962           G2020       ORG    CA            24E
# 963           G2020       ORG    CA            24E

# %%
df_presidential['STATE'].unique()
# Out:
# array(['CA', 'DC', 'RI', 'PA', 'KS', 'WI', 'FL', 'VA', 'AL', nan, 'AZ',
#        'GA', 'NJ', 'IA', 'NY', 'MI', 'MN', 'IL', 'MA', 'TX', 'OR', 'NE',
#        'NC', 'WA', 'OH', 'MD', 'VI', 'DE', 'IN'], dtype=object)

# %%
# Filter to US states only
us_states = ['AL', 'AK', 'AZ', 'AR', 'CA', 'CO', 'CT', 'DE', 'FL', 'GA', 
             'HI', 'ID', 'IL', 'IN', 'IA', 'KS', 'KY', 'LA', 'ME', 'MD', 
             'MA', 'MI', 'MN', 'MS', 'MO', 'MT', 'NE', 'NV', 'NH', 'NJ', 
             'NM', 'NY', 'NC', 'ND', 'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 
             'SD', 'TN', 'TX', 'UT', 'VT', 'VA', 'WA', 'WV', 'WI', 'WY', 'DC']

df_presidential = df_presidential[df_presidential['STATE'].isin(us_states)]

# %%
df_presidential.shape
# Out:
# (1031, 9)

# %%
df_presidential.isnull().sum()
# Out:
# NAME                 0
# CAND_ID              0
# CMTE_ID              0
# TRANSACTION_DT     183
# TRANSACTION_AMT      0
# TRANSACTION_PGI      0
# ENTITY_TP            1
# STATE                0
# TRANSACTION_TP       0
# dtype: int64

# %%
df_presidential = df_presidential.dropna(subset=['TRANSACTION_DT'])

# %%
df_presidential.shape
# Out:
# (848, 9)

# %%
df_presidential.isnull().sum()
# Out:
# NAME               0
# CAND_ID            0
# CMTE_ID            0
# TRANSACTION_DT     0
# TRANSACTION_AMT    0
# TRANSACTION_PGI    0
# ENTITY_TP          1
# STATE              0
# TRANSACTION_TP     0
# dtype: int64

# %%
df_presidential['ENTITY_TP'].unique()
# Out:
# array(['ORG', nan, 'CCM', 'IND', 'COM', 'PAC', 'CAN'], dtype=object)

# %%
df_presidential['ENTITY_TP'] = df_presidential['ENTITY_TP'].fillna('IND')

# %%
# Map entity type codes to full names
entity_mapping = {
    'IND': 'Individual',
    'COM': 'Committee',
    'PAC': 'Political Action Committee',
    'ORG': 'Organization',
    'CCM': 'Candidate Committee',
    'CAN': 'Candidate',
    'PTY': 'Party Organization'
}

df_presidential['ENTITY_TP'] = df_presidential['ENTITY_TP'].map(entity_mapping)

# %%
df_presidential.isnull().sum()
# Out:
# NAME               0
# CAND_ID            0
# CMTE_ID            0
# TRANSACTION_DT     0
# TRANSACTION_AMT    0
# TRANSACTION_PGI    0
# ENTITY_TP          0
# STATE              0
# TRANSACTION_TP     0
# dtype: int64

# %%
df_presidential.dtypes
# Out:
# NAME                object
# CAND_ID             object
# CMTE_ID             object
# TRANSACTION_DT     float64
# TRANSACTION_AMT      int64
# TRANSACTION_PGI     object
# ENTITY_TP           object
# STATE               object
# TRANSACTION_TP      object
# dtype: object

# %%
df_presidential['TRANSACTION_DT'] = pd.to_datetime(df_presidential['TRANSACTION_DT'], format='%m%d%Y')

# %%
df_presidential.dtypes
# Out:
# NAME                       object
# CAND_ID                    object
# CMTE_ID                    object
# TRANSACTION_DT     datetime64[ns]
# TRANSACTION_AMT             int64
# TRANSACTION_PGI            object
# ENTITY_TP                  object
# STATE                      object
# TRANSACTION_TP             object
# dtype: object

# %%
# Map state codes to full names
state_mapping = {
    'AL': 'Alabama', 'AK': 'Alaska', 'AZ': 'Arizona', 'AR': 'Arkansas',
    'CA': 'California', 'CO': 'Colorado', 'CT': 'Connecticut', 'DE': 'Delaware',
    'FL': 'Florida', 'GA': 'Georgia', 'HI': 'Hawaii', 'ID': 'Idaho',
    'IL': 'Illinois', 'IN': 'Indiana', 'IA': 'Iowa', 'KS': 'Kansas',
    'KY': 'Kentucky', 'LA': 'Louisiana', 'ME': 'Maine', 'MD': 'Maryland',
    'MA': 'Massachusetts', 'MI': 'Michigan', 'MN': 'Minnesota', 'MS': 'Mississippi',
    'MO': 'Missouri', 'MT': 'Montana', 'NE': 'Nebraska', 'NV': 'Nevada',
    'NH': 'New Hampshire', 'NJ': 'New Jersey', 'NM': 'New Mexico', 'NY': 'New York',
    'NC': 'North Carolina', 'ND': 'North Dakota', 'OH': 'Ohio', 'OK': 'Oklahoma',
    'OR': 'Oregon', 'PA': 'Pennsylvania', 'RI': 'Rhode Island', 'SC': 'South Carolina',
    'SD': 'South Dakota', 'TN': 'Tennessee', 'TX': 'Texas', 'UT': 'Utah',
    'VT': 'Vermont', 'VA': 'Virginia', 'WA': 'Washington', 'WV': 'West Virginia',
    'WI': 'Wisconsin', 'WY': 'Wyoming', 'DC': 'District of Columbia'
}

df_presidential['STATE'] = df_presidential['STATE'].map(state_mapping)

# %%
df_presidential.to_csv("Expen_Can_Com_Indep_2021_2022.csv", index=False)
